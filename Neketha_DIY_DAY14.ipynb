# %% [markdown]
# <a href="https://colab.research.google.com/github/nekethamahendran/Datascience/blob/main/Neketha_DIY_DAY14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handling Null-Values

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/titanic.csv")
df.head()
# Out:
#    Unnamed: 0  Survived  Pclass                                          Name  \
# 0         NaN         0       3                              Kelly, Mr. James
# 1       893.0         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2       894.0         0       2                     Myles, Mr. Thomas Francis
# 3       895.0         0       3                              Wirz, Mr. Albert
# 4       896.0         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0    male  34.5      0      0   330911   7.8292   NaN        Q
# 1  female  47.0      1      0   363272   7.0000   NaN        S
# 2    male  62.0      0      0   240276   9.6875   NaN        Q
# 3    male  27.0      0      0   315154   8.6625   NaN        S
# 4  female  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 12)

# %%
print("Indentifying the Null Values:")
print(df.isnull().sum())
# Out:
# Indentifying the Null Values:
# Unnamed: 0      1
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Cabin         327
# Embarked        0
# dtype: int64

# %%
df2=df.dropna()
df2.head(10)
# Out:
#     Unnamed: 0  Survived  Pclass  \
# 12       904.0         1       1
# 14       906.0         1       1
# 24       916.0         1       1
# 26       918.0         1       1
# 28       920.0         0       1
# 34       926.0         0       1
# 44       936.0         1       1
# 46       938.0         0       1
# 48       940.0         1       1
# 50       942.0         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                            Brady, Mr. John Bertram    male  41.0      0
# 34                           Mock, Mr. Philipp Edmund    male  30.0      1
# ...

# %%
df2.isnull()
# Out:
#      Unnamed: 0  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 12        False     False   False  False  False  False  False  False   False
# 14        False     False   False  False  False  False  False  False   False
# 24        False     False   False  False  False  False  False  False   False
# 26        False     False   False  False  False  False  False  False   False
# 28        False     False   False  False  False  False  False  False   False
# ..          ...       ...     ...    ...    ...    ...    ...    ...     ...
# 404       False     False   False  False  False  False  False  False   False
# 405       False     False   False  False  False  False  False  False   False
# 407       False     False   False  False  False  False  False  False   False
# 411       False     False   False  False  False  False  False  False   False
# 414       False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# # Handling Duplicate Values

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/titanic.csv")
df.head(10)
# Out:
#    Unnamed: 0  Survived  Pclass                                          Name  \
# 0         NaN         0       3                              Kelly, Mr. James
# 1       893.0         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2       894.0         0       2                     Myles, Mr. Thomas Francis
# 3       895.0         0       3                              Wirz, Mr. Albert
# 4       896.0         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5       897.0         0       3                    Svensson, Mr. Johan Cervin
# 6       898.0         1       3                          Connolly, Miss. Kate
# 7       899.0         0       2                  Caldwell, Mr. Albert Francis
# 8       900.0         1       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9       901.0         0       3                       Davies, Mr. John Samuel
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
df.duplicated().any()
# Out:
# False

# %%
df.duplicated(subset="Ticket").any()
# Out:
# True

# %%
df2=df.drop_duplicates(subset="Ticket")
df2
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0           NaN         0       3
# 1         893.0         1       3
# 2         894.0         0       2
# 3         895.0         0       3
# 4         896.0         1       3
# ..          ...       ...     ...
# 413      1305.0         0       3
# 414      1306.0         1       1
# 415      1307.0         0       3
# 416      1308.0         0       3
# 417      1309.0         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...
